# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("parthplc/medical-image-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.11).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/parthplc/medical-image-dataset?dataset_version_number=1...
# 100%|██████████████████████████████████████| 13.0M/13.0M [00:04<00:00, 2.89MB/s]
# Extracting files...
# Path to dataset files: /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1

# %%
import numpy as np
import pandas as pd
import os

dataset_path = "/Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1"

# Iterate over all files in the dataset directory
for dirname, _, filenames in os.walk(dataset_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/63.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/77.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/88.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/89.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/76.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/62.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/74.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/60.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/48.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/49.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/61.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/75.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/59.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/71.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/65.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/64.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/70.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/58.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/8.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/66.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/72.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/99.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/98.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/73.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/67.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/9.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/14.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/28.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/101.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/115.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/114.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/100.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/29.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/15.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/17.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/116.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/102.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/103.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/117.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/16.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/12.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/113.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/107.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/106.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/112.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/13.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/39.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/11.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/104.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/110.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/111.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/105.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/10.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/38.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/21.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/35.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/108.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/120.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/109.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/34.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/20.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/36.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/22.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/23.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/37.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/33.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/27.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/26.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/32.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/18.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/24.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/30.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/119.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/118.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/31.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/25.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/19.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/42.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/4.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/56.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/81.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/95.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/94.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/80.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/5.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/57.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/43.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/55.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/7.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/41.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/69.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/96.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/82.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/83.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/97.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/68.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/40.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/54.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/6.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/78.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/2.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/50.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/44.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/93.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/87.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/86.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/92.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/45.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/3.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/51.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/79.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/47.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/53.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/1.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/84.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/90.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/91.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/85.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/52.jpg
# /Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset/46.jpg

# %%
dataset_path = "/Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset"

# Get a sorted list of training images
train_images = sorted(os.listdir(dataset_path))

print("Total images:", len(train_images))
print("First 5 images:", train_images[:5])  # Print the first 5 image names
# Out:
# Total images: 120
# First 5 images: ['1.jpg', '10.jpg', '100.jpg', '101.jpg', '102.jpg']

# %%
import numpy as np
import os
from tensorflow.keras.preprocessing import image

# Define dataset path
dataset_path = "/Users/himanshujha/.cache/kagglehub/datasets/parthplc/medical-image-dataset/versions/1/Dataset"

# Get sorted list of images
train_images = sorted(os.listdir(dataset_path))

# Initialize an empty list to store processed images
train_image = []

# Loop through each image, load it, and preprocess
for im in train_images:
    img_path = os.path.join(dataset_path, im)
    
    # Load image in grayscale mode and resize
    img = image.load_img(img_path, target_size=(64, 64), color_mode='grayscale')
    
    # Convert image to array
    img = image.img_to_array(img)
    
    # Normalize pixel values to range [0, 1]
    img = img / 255.0  
    
    # Append to list
    train_image.append(img)

# Convert list to NumPy array
train_df = np.array(train_image)

print("Shape of dataset:", train_df.shape)  # (num_samples, 64, 64, 1)
# Out:
# Shape of dataset: (120, 64, 64, 1)

# %%
import matplotlib.pyplot as plt

def show_img(dataset):
    f, ax = plt.subplots(1, 5)  # Create 1 row, 5 columns
    f.set_size_inches(40, 20)  # Adjust figure size
    
    for i in range(5):  # Fix indexing issue (i runs from 0 to 4)
        ax[i].imshow(dataset[i+5].reshape(64, 64), cmap='gray')  # Shift index
        # Hide axes for better visualization

    plt.show()

# %%
import numpy as np

def add_noise(image):
    # Ensure image has correct shape (64, 64, 1) for grayscale
    if len(image.shape) == 2:  # If shape is (64, 64), add a channel dimension
        image = image.reshape(image.shape[0], image.shape[1], 1)

    row, col, ch = image.shape
    mean = 0
    sigma = 1  # Standard deviation
    gauss = np.random.normal(mean, sigma, (row, col, ch))  # Generate Gaussian noise
    
    noisy = image + gauss * 0.07  # Scale noise intensity
    noisy = np.clip(noisy, 0, 1)  # Clip values to keep them in valid range [0, 1]
    
    return noisy

# %%
noisy_image = add_noise(train_df[0])  # Apply noise to the first image
print(noisy_image.shape)
# Out:
# (64, 64, 1)

# %%
noised_df = []

for img in train_df:
    noisy = add_noise(img)  # Fix function name
    noised_df.append(noisy)

# Convert list to NumPy array
noised_df = np.array(noised_df)

print("Shape of noised dataset:", noised_df.shape)  # Should match train_df.shape
# Out:
# Shape of noised dataset: (120, 64, 64, 1)

# %%
show_img(noised_df)

# %%
xclean = train_df[0:100]
xclean_test = train_df[100:]
xnoised= noised_df[0:100]
xtest= noised_df[100:]

# %%
show_img(xclean)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

# Convolutional Block
def ConvBlock(x, filters):
    x = layers.Conv2D(filters, kernel_size=3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, kernel_size=3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    return x

# Upsampling Block
def UpConv(x, skip, filters):
    x = layers.Conv2DTranspose(filters, kernel_size=2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])  # Skip connection
    x = ConvBlock(x, filters)
    
    return x

# U-Net Model
def UNet(input_shape=(64, 64, 1), num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    e1 = ConvBlock(inputs, 64)
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(e1)

    e2 = ConvBlock(p1, 128)
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(e2)

    e3 = ConvBlock(p2, 256)
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(e3)

    e4 = ConvBlock(p3, 512)
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(e4)

    e5 = ConvBlock(p4, 1024)  # Bottleneck

    # Decoder
    d1 = UpConv(e5, e4, 512)
    d2 = UpConv(d1, e3, 256)
    d3 = UpConv(d2, e2, 128)
    d4 = UpConv(d3, e1, 64)

    # Output layer
    outputs = layers.Conv2D(num_classes, kernel_size=1, activation="sigmoid")(d4)

    return Model(inputs, outputs)

# Instantiate the model
model = UNet(input_shape=(64, 64, 1), num_classes=1)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 64, 64,    │        640 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_18[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 32, 32,    │          0 │ re_lu_19[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │     73,856 │ max_pooling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_20[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 16, 16,    │          0 │ re_lu_21[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 16, 16,    │    295,168 │ max_pooling2d_5[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_22[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 8, 8, 256) │          0 │ re_lu_23[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8, 512) │  1,180,160 │ max_pooling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 8, 8, 512) │  2,359,808 │ re_lu_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 4, 4, 512) │          0 │ re_lu_25[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 4, 4,      │  4,719,616 │ max_pooling2d_7[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      4,096 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 4, 4,      │  9,438,208 │ re_lu_26[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      4,096 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 8, 8, 512) │  2,097,664 │ re_lu_27[0][0]    │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ re_lu_25[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 8, 8, 512) │  4,719,104 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 8, 8, 512) │  2,359,808 │ re_lu_28[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 16, 16,    │    524,544 │ re_lu_29[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 16, 16,    │  1,179,904 │ concatenate_5[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_30[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 32, 32,    │    131,200 │ re_lu_31[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 32, 32,    │    295,040 │ concatenate_6[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_32[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 64, 64,    │     32,832 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │     73,792 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_34[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 64, 64, 1) │         65 │ re_lu_35[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,054,145 (118.46 MB)
#  Trainable params: 31,042,369 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import os

# Disable GPU usage
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Forces TensorFlow to ignore the GPU

# Verify CPU is being used
print("Num GPUs Available:", len(tf.config.experimental.list_physical_devices('GPU')))
print("Running on:", tf.config.experimental.list_physical_devices('CPU'))

# Compile the model for denoising
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',  # Use 'mae' if you prefer absolute error
    metrics=['mae']  # Monitor Mean Absolute Error as an additional metric
)

# Define Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=1,
    mode='auto',
    restore_best_weights=True
)

# Train the model on CPU
history = model.fit(
    xnoised, xclean,  # X = Noisy images, Y = Clean images
    epochs=40,
    batch_size=10,
    validation_data=(xtest, xclean_test),  # Use clean validation images
    callbacks=[early_stopping]
)
# Out:
# Num GPUs Available: 0
# Running on: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Epoch 1/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 981ms/step - loss: 0.0147 - mae: 0.0848 - val_loss: 0.0658 - val_mae: 0.2114
# Epoch 2/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 966ms/step - loss: 0.0036 - mae: 0.0447 - val_loss: 0.1456 - val_mae: 0.3303
# Epoch 3/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 924ms/step - loss: 0.0027 - mae: 0.0392 - val_loss: 0.0839 - val_mae: 0.2404
# Epoch 4/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 954ms/step - loss: 0.0022 - mae: 0.0358 - val_loss: 0.0950 - val_mae: 0.2616
# Epoch 5/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 970ms/step - loss: 0.0025 - mae: 0.0386 - val_loss: 0.0563 - val_mae: 0.1901
# Epoch 6/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 981ms/step - loss: 0.0022 - mae: 0.0362 - val_loss: 0.0545 - val_mae: 0.1873
# Epoch 7/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 993ms/step - loss: 0.0021 - mae: 0.0359 - val_loss: 0.0558 - val_mae: 0.1911
# Epoch 8/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0533 - val_mae: 0.1854
# Epoch 9/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0524 - val_mae: 0.1841
# Epoch 10/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0028 - mae: 0.0411 - val_loss: 0.0517 - val_mae: 0.1832
# Epoch 11/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0022 - mae: 0.0363 - val_loss: 0.0494 - val_mae: 0.1786
# Epoch 12/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - loss: 0.0022 - mae: 0.0369 - val_loss: 0.0485 - val_mae: 0.1774
# Epoch 13/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0469 - val_mae: 0.1741
# Epoch 14/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0016 - mae: 0.0311 - val_loss: 0.0460 - val_mae: 0.1722
# Epoch 15/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0018 - mae: 0.0325 - val_loss: 0.0456 - val_mae: 0.1711
# Epoch 16/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0016 - mae: 0.0315 - val_loss: 0.0442 - val_mae: 0.1684
# Epoch 17/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0432 - val_mae: 0.1660
# Epoch 18/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0020 - mae: 0.0352 - val_loss: 0.0431 - val_mae: 0.1657
# Epoch 19/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0022 - mae: 0.0364 - val_loss: 0.0413 - val_mae: 0.1617
# Epoch 20/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0404 - val_mae: 0.1597
# Epoch 21/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0019 - mae: 0.0337 - val_loss: 0.0397 - val_mae: 0.1583
# Epoch 22/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0017 - mae: 0.0312 - val_loss: 0.0388 - val_mae: 0.1559
# Epoch 23/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0016 - mae: 0.0305 - val_loss: 0.0385 - val_mae: 0.1550
# Epoch 24/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0379 - val_mae: 0.1537
# Epoch 25/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0017 - mae: 0.0320 - val_loss: 0.0353 - val_mae: 0.1471
# Epoch 26/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0016 - mae: 0.0304 - val_loss: 0.0366 - val_mae: 0.1502
# Epoch 27/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0015 - mae: 0.0297 - val_loss: 0.0349 - val_mae: 0.1461
# Epoch 28/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0022 - mae: 0.0365 - val_loss: 0.0348 - val_mae: 0.1459
# Epoch 29/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0018 - mae: 0.0326 - val_loss: 0.0347 - val_mae: 0.1459
# Epoch 30/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0331 - val_mae: 0.1419
# Epoch 31/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0017 - mae: 0.0315 - val_loss: 0.0319 - val_mae: 0.1391
# Epoch 32/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0015 - mae: 0.0297 - val_loss: 0.0318 - val_mae: 0.1389
# Epoch 33/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0015 - mae: 0.0305 - val_loss: 0.0298 - val_mae: 0.1341
# Epoch 34/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0306 - val_mae: 0.1364
# Epoch 35/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0019 - mae: 0.0347 - val_loss: 0.0291 - val_mae: 0.1330
# Epoch 36/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0267 - val_mae: 0.1271
# Epoch 37/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0016 - mae: 0.0313 - val_loss: 0.0270 - val_mae: 0.1278
# Epoch 38/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0018 - mae: 0.0328 - val_loss: 0.0259 - val_mae: 0.1252
# Epoch 39/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0020 - mae: 0.0347 - val_loss: 0.0238 - val_mae: 0.1191
# Epoch 40/40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.0017 - mae: 0.0317 - val_loss: 0.0219 - val_mae: 0.1144
# Restoring model weights from the end of the best epoch: 40.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Generate predictions
pred = model.predict(xtest[:5])

def plot_predictions(y_true, y_pred, x_noised):
    f, ax = plt.subplots(3, 5, figsize=(12, 8))

    for i in range(5):
        # Noisy Input
        ax[0, i].imshow(x_noised[i].squeeze(), aspect='auto', cmap='gray')
        ax[0, i].set_title("Noisy")
        

        # Ground Truth (Clean Image)
        ax[1, i].imshow(y_true[i].squeeze(), aspect='auto', cmap='gray')
        ax[1, i].set_title("Clean")
        

        # Model Prediction (Denoised Output)
        ax[2, i].imshow(y_pred[i].squeeze(), aspect='auto', cmap='gray')
        ax[2, i].set_title("Denoised")
        

        
        

    plt.tight_layout()
    plt.show()

# Call the function with correct inputs
plot_predictions(xclean_test[:5], pred[:5], xtest[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step

# %%
from math import log10, sqrt 
  
def PSNR(original, denoiced): 
    mse = np.mean((original - denoiced) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr 
  

value2 = PSNR(xtest[0], pred[0])

print(f"PSNR value for Denoised image is {value2} dB ")
# Out:
# PSNR value for Denoised image is 64.52217308727198 dB
